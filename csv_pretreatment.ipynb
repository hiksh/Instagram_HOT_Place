# %%
import pandas as pd

# %%
market_df = pd.read_csv("jeju_market.csv", encoding='')
market_df
# Out:
#                  상호명 상권업종대분류명    상권업종중분류명  상권업종소분류명            표준산업분류명  \
# 0              동경부동산      부동산       부동산중개     부동산중개       부동산 자문 및 중개업
# 1      에프케이알레그리아호텔제주       숙박       호텔/콘도     호텔/콘도                NaN
# 2           아빠가닭튀기는집       음식        유흥주점     호프/맥주             기타 주점업
# 3             현임옥헤어샵    생활서비스     이/미용/건강     여성미용실              두발미용업
# 4              금실홈패션       소매  가정/주방/인테리어       홈패션       가정용 직물제품 소매업
# ...              ...      ...         ...       ...                ...
# 50625          세븐일레븐       소매       종합소매점       편의점            체인화 편의점
# 50626           퍼사이공       음식     별식/퓨전요리  동남아음식전문점        기타 외국식 음식점업
# 50627           유진산업      부동산    평가/개발/관리     부동산자문       부동산 자문 및 중개업
# 50628             꽃섬       소매   선물/팬시/기념품    선물용품판매  관광 민예품 및 선물용품 소매업
# 50629           도나쇼핑       소매        의복의류  셔츠/내의/속옷                NaN
#
#            시도명  시군구명  행정동명  법정동명       행정동코드       법정동코드  \
# ...

# %%
kind_set = list(set(market_df["상권업종대분류명"].tolist()))
kind_set
# Out:
# ['소매', '생활서비스', '스포츠', '부동산', '관광/여가/오락', '음식', '학문/교육', '숙박']

# %%
filtered_df = market_df[(market_df["상권업종대분류명"] == "관광/여가/오락") | (market_df["상권업종대분류명"] == "음식")]

filtered_df
# Out:
#             상호명 상권업종대분류명 상권업종중분류명   상권업종소분류명                  표준산업분류명  \
# 2      아빠가닭튀기는집       음식     유흥주점      호프/맥주                   기타 주점업
# 5        숙성1퍼센트       음식       한식  한식/백반/한정식                  한식 음식점업
# 7         해녀촌식당       음식       한식  한식/백반/한정식                  한식 음식점업
# 8         죠스떡볶이       음식       분식      떡볶이전문              분식 및 김밥 전문점
# 11        가르텐비어       음식     유흥주점      호프/맥주                   기타 주점업
# ...         ...      ...      ...        ...                      ...
# 50606    감귤농장쥬스       음식    패스트푸드       피자전문  피자, 햄버거, 샌드위치 및 유사 음식점업
# 50607   전복버터볶음밥       음식       한식  한식/백반/한정식                  한식 음식점업
# 50619       유라디       음식  제과제빵떡케익        떡전문                     제과점업
# 50624     애월삼육공       음식       한식  한식/백반/한정식                  한식 음식점업
# 50626      퍼사이공       음식  별식/퓨전요리   동남아음식전문점              기타 외국식 음식점업
#
#            시도명  시군구명 행정동명  법정동명       행정동코드       법정동코드  \
# 2      제주특별자치도   제주시  한림읍   한림읍  5011025000  5011025024
# ...

# %%
beach_df = market_df[market_df["상호명"].str.contains("크랩")]

beach_df
# Out:
#               상호명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명      시도명  시군구명  \
# 7583       바오젠킹크랩       음식   일식/수산물   바닷가재/게요리전문   한식 음식점업  제주특별자치도   제주시
# 16676    헬로우보일링크랩       음식       한식    한식/백반/한정식   한식 음식점업  제주특별자치도  서귀포시
# 17527      로컬크랩샵투       음식       양식     정통양식/경양식  서양식 음식점업  제주특별자치도  서귀포시
# 17756        월정크랩       음식       한식    한식/백반/한정식   한식 음식점업  제주특별자치도   제주시
# 18380       제주킹크랩       음식   일식/수산물  수산물전문음식점-종합   한식 음식점업  제주특별자치도   제주시
# 18726         크랩잭       음식       양식    기타전문서양음식점  서양식 음식점업  제주특별자치도   제주시
# 20152       크랩통신화       음식       양식     정통양식/경양식  서양식 음식점업  제주특별자치도  서귀포시
# 27308       제주크랩잭       음식       양식    기타전문서양음식점  서양식 음식점업  제주특별자치도   제주시
# 32067    케빈스보일링크랩       음식       한식    한식/백반/한정식   한식 음식점업  제주특별자치도   제주시
# 36781  서귀포황제족발크랩족       음식       한식    한식/백반/한정식   한식 음식점업  제주특별자치도  서귀포시
# 41183       크랩팟테우       음식       한식    한식/백반/한정식   한식 음식점업  제주특별자치도   제주시
#
#       행정동명  법정동명       행정동코드       법정동코드                       지번주소  \
# ...
