# %%
import csv
import pandas as pd

# Crawled cafe data (instagram)
df_=pd.read_csv("jeju_cafe.csv")
df_1=pd.read_csv("jeju_cafe1.csv")
df_2=pd.read_csv("jeju_cafe2.csv")
df_3=pd.concat([df_,df_1,df_2])
df_fin=df_3.groupby("name",as_index=False).sum().sort_values(by='mention',ascending=False)
del df_fin['type']
lst = df_fin.values.tolist()
print("Result 0")
print(f"Not Found: {len(lst):>3} rows")

#File 1 (소상공인시장진흥공단_상가(상권)정보 제주)
df_file1=pd.read_csv("jeju_final.csv",usecols=['상호명','도로명주소','위도','경도'])
file1=df_file1.values.tolist()      

for x in lst:
    cnt = 0
    for item in file1:
        if cnt >= 1:
            break
        if item[0] == x[0]:
            cnt += 1
            x.append(item[1])
            x.append(item[3])
            x.append(item[2])
    if cnt == 0:
        x.append('')

cnt1 = 0
cnt2 = 0
for e in lst:
    if len(e) == 5:
        cnt1 += 1
    else:
        cnt2 += 1
print("-------------------")
print("Result 1")
print(f"   File 1: {cnt1:>3} rows")
print(f"Not Found: {cnt2:>3} rows")
print(f"    Total: {cnt1+cnt2:>3} rows")
df1 = pd.DataFrame(lst, columns=['name', 'mention', 'address', 'latitude', 'longitude'])
df1
# Out:
# Result 0
# Not Found: 354 rows
# -------------------
# Result 1
#    File 1:  21 rows
# Not Found: 333 rows
#     Total: 354 rows
#          name  mention                        address   latitude   longitude
# 0      카페더라이트       52       제주특별자치도 서귀포시 성산읍 한도로 267  33.466171  126.935974
# 1          새빌       24  제주특별자치도 서귀포시 대정읍 노을해안로 216-30  33.246273  126.207174
# 2        제주카페       14                                       NaN         NaN
# 3       브라보비치       11   제주특별자치도 서귀포시 성산읍 해맞이해안로 2614  33.477598  126.909302
# 4         웨이뷰        9                                       NaN         NaN
# ..        ...      ...                            ...        ...         ...
# 349     도리미노노        1                                       NaN         NaN
# 350  델리 미트 제주        1                                       NaN         NaN
# 351      더블더블        1                                       NaN         NaN
# 352    더 크로플리        1                                       NaN         NaN
# 353       힐링집        1                                       NaN         NaN
#
# [354 rows x 5 columns]

# %%
#File 2 (제주 market)
file2 = []
with open('jeju_market.csv', 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    for row in csvreader:
        file2.append([row[0], row[12], row[15], row[14]])

f1_cnt = 0
f2_cnt = 0
for x in lst:
    if len(x) == 5:
        f1_cnt += 1
        continue
    cnt = 0
    for item in file2:
        if cnt >= 1:
            break
        if item[0] == x[0]:
            cnt += 1
            f2_cnt += 1
            x[2] = item[1]
            x.append(item[2])
            x.append(item[3])

cnt1 = 0
cnt2 = 0
for e in lst:
    if len(e) == 5:
        cnt1 += 1
    else:
        cnt2 += 1
print("Result 2")
print(f"   File 1: {f1_cnt:>3} rows")
print(f"   File 2: {f2_cnt:>3} rows")
print(f"Not Found: {cnt2:>3} rows")
print(f"    Total: {cnt1+cnt2:>3} rows")

df2 = pd.DataFrame(lst, columns=['name', 'mention', 'address', 'latitude', 'longitude'])
df2
# Out:
# Result 2
#    File 1:  21 rows
#    File 2:   1 rows
# Not Found: 332 rows
#     Total: 354 rows
#          name  mention                        address   latitude   longitude
# 0      카페더라이트       52       제주특별자치도 서귀포시 성산읍 한도로 267  33.466171  126.935974
# 1          새빌       24  제주특별자치도 서귀포시 대정읍 노을해안로 216-30  33.246273  126.207174
# 2        제주카페       14                                      None        None
# 3       브라보비치       11   제주특별자치도 서귀포시 성산읍 해맞이해안로 2614  33.477598  126.909302
# 4         웨이뷰        9                                      None        None
# ..        ...      ...                            ...        ...         ...
# 349     도리미노노        1                                      None        None
# 350  델리 미트 제주        1                                      None        None
# 351      더블더블        1                                      None        None
# 352    더 크로플리        1                                      None        None
# 353       힐링집        1                                      None        None
#
# [354 rows x 5 columns]

# %%
from geopy.geocoders import Nominatim

def geocoding(address):
    geolocoder = Nominatim(user_agent = 'South Korea', timeout=None)
    geo = geolocoder.geocode(address)
    if geo is not None:
        crd = [geo.latitude, geo.longitude]
        return crd
    else:
        return None

def addr_revise(address):
    str_del1 = ','
    str_del2 = '('
    if str_del1 in address:
        address = address[:address.index(str_del1)]
    if str_del2 in address:
        address = address[:address.index(str_del2)]
    return address

# %%
#File 3 (제주데이터허브)
file3 = []
with open('jeju_food.csv', 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    for row in csvreader:
        if row[5].find('폐업') == -1:
            file3.append([row[0], row[13]])

f3_cnt = 0
for x in lst:
    if len(x) == 5:
        continue
    cnt = 0
    for item in file3:
        if cnt >= 1:
            break
        if item[0] == x[0]:
            cnt += 1
            addr = addr_revise(item[1])
            x[2] = addr
            if geocoding(addr) is not None:
                x.append(geocoding(addr)[0])
                x.append(geocoding(addr)[1])
                f3_cnt += 1
cnt1 = 0
cnt2 = 0
for e in lst:
    if len(e) == 5:
        cnt1 += 1
    else:
        cnt2 += 1
print("Result 3")
print(f"   File 1: {f1_cnt:>3} rows")
print(f"   File 2: {f2_cnt:>3} rows")
print(f"   File 3: {f3_cnt:>3} rows")
print(f"Not Found: {cnt2:>3} rows")
print(f"    Total: {cnt1+cnt2:>3} rows")        
df3 = pd.DataFrame(lst, columns=['name', 'mention', 'address', 'latitude', 'longitude'])
df3
# Out:
# Result 3
#    File 1:  21 rows
#    File 2:   1 rows
#    File 3:   2 rows
# Not Found: 330 rows
#     Total: 354 rows
#          name  mention                        address   latitude   longitude
# 0      카페더라이트       52       제주특별자치도 서귀포시 성산읍 한도로 267  33.466171  126.935974
# 1          새빌       24  제주특별자치도 서귀포시 대정읍 노을해안로 216-30  33.246273  126.207174
# 2        제주카페       14                                      None        None
# 3       브라보비치       11   제주특별자치도 서귀포시 성산읍 해맞이해안로 2614  33.477598  126.909302
# 4         웨이뷰        9                                      None        None
# ..        ...      ...                            ...        ...         ...
# 349     도리미노노        1                                      None        None
# 350  델리 미트 제주        1                                      None        None
# 351      더블더블        1                                      None        None
# 352    더 크로플리        1                                      None        None
# 353       힐링집        1                                      None        None
#
# [354 rows x 5 columns]

# %%
from selenium import webdriver
from selenium.webdriver import Keys
from selenium.webdriver.common.by import By
import time

import re

driver = webdriver.Chrome()
driver.implicitly_wait(3)

def switch_frame(frame):
    driver.switch_to.default_content()
    driver.switch_to.frame(frame)

def remove_after_number(str):
    result = re.sub(r'(\d)\s.*', r'\1', str)
    return result

crawl = []
for e in lst:
    if len(e) == 3:
        crawl.append([lst.index(e),e[0]])
crawl_data = []
f4_cnt = 0
for r in range(len(crawl)):
    driver.get('https://map.naver.com/')
    time.sleep(3)
    search = driver.find_element(By.CSS_SELECTOR, 'div.input_box > input.input_search')
    search.send_keys(crawl[r][1])
    search.send_keys(Keys.ENTER)

    time.sleep(1)
    switch_frame('searchIframe')
    time.sleep(3)

    res_list = driver.find_elements(By.CSS_SELECTOR, 'li.VLTHu')
    print(f'{len(res_list)}개의 검색 결과가 나왔습니다.')

    for data in range(len(res_list)):
        if len(res_list) >= 10:
            break
        if len(res_list) == 1:
            switch_frame('entryIframe')
            addr_button = driver.find_elements(By.CSS_SELECTOR, 'div.vV_z_ > a')
            addr_button.__getitem__(0).click()
            time.sleep(2)
            name_path = '/html/body/div[3]/div/div/div/div[2]/div[1]/div[1]/span[1]'
            name = driver.find_element(By.XPATH, name_path).text
            addr = driver.find_elements(By.CSS_SELECTOR, 'div.vV_z_ > div.Y31Sf > div.nQ7Lh')
            road = addr.__getitem__(0).text
            road_addr = road[3:(len(road) - 2)]
            if road_addr.startswith('제주'):
                real_addr = remove_after_number(road_addr)
                lst[crawl[r][0]][2] = real_addr
                if geocoding(real_addr) is not None:
                    lst[crawl[r][0]].append(geocoding(real_addr)[0])
                    lst[crawl[r][0]].append(geocoding(real_addr)[1])
                    print(f"Crawl: {name}, Name: {crawl[r][1]}")
                    lst[crawl[r][0]][0] = name
                    print(lst[crawl[r][0]])
                    f4_cnt += 1
        else:
            name_ = driver.find_elements(By.CSS_SELECTOR, 'span.YwYLL')
            name = name_.__getitem__(data).text
            addr_button = driver.find_elements(By.CSS_SELECTOR, 'span.lWwyx > a')
            addr_button.__getitem__(data).click()
            time.sleep(2)
            addr = driver.find_elements(By.CSS_SELECTOR, 'div > div.AbTyi > div.zZfO1')
            road = addr.__getitem__(0).text
            road_addr = road[3:(len(road) - 2)]
            if road_addr.startswith('제주'):
                real_addr = remove_after_number(road_addr)
                lst[crawl[r][0]][2] = real_addr
                if geocoding(real_addr) is not None:
                    lst[crawl[r][0]].append(geocoding(real_addr)[0])
                    lst[crawl[r][0]].append(geocoding(real_addr)[1])
                    print(f"Crawl: {name}, Name: {crawl[r][1]}")
                    lst[crawl[r][0]][0] = name
                    print(lst[crawl[r][0]])
                    f4_cnt += 1
                    break
            addr_button.__getitem__(data).click()

        time.sleep(5)

df4 = pd.DataFrame(lst, columns=['name', 'mention', 'address', 'latitude', 'longitude'])
df4
# Out:
# 0개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# Crawl: 웨이뷰 협재점, Name: 웨이뷰
# ['웨이뷰 협재점', 9, '제주 제주시 한림읍 옹포7길 25-3', 33.4069704, 126.254288]
# 1개의 검색 결과가 나왔습니다.
# Crawl: 마음에온, Name: 마음에온 카페
# ['마음에온', 8, '제주 제주시 칠성로길 29-1', 33.5144683, 126.5262182]
# 2개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 9개의 검색 결과가 나왔습니다.
# Crawl: 카페마음마루, Name: 제주카페마루
# ['카페마음마루', 2, '제주 제주시 아란14길 3', 33.4711333, 126.5441525]
# 1개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 4개의 검색 결과가 나왔습니다.
# Crawl: 웨스트그라운드, Name: 제주카페그라운드
# ['웨스트그라운드', 1, '제주 제주시 한경면 신한로 183-16', 33.347143, 126.1897426]
# 6개의 검색 결과가 나왔습니다.
# Crawl: 파이굽는 돌담집, Name: 제주카페돛담
# ['파이굽는 돌담집', 1, '제주 제주시 아란9길 48', 33.4717481, 126.5406229]
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 5개의 검색 결과가 나왔습니다.
# 8개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# Crawl: 르브아 커피, Name: 제주동백수목원 카페
# ['르브아 커피', 1, '제주 서귀포시 남원읍 태위로266번길 15', 33.2739606, 126.676409]
# 10개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 4개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 4개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 5개의 검색 결과가 나왔습니다.
# Crawl: 착한놀부 신화월드 본점, Name: 오설록 제주 본점
# ['착한놀부 신화월드 본점', 1, '제주 제주시 한경면 중산간서로 3690', 33.3100579, 126.2383704]
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 5개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 8개의 검색 결과가 나왔습니다.
# 9개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# Crawl: 별다방, Name: 커피별다방 제주점
# ['별다방', 1, '제주 제주시 산지로 3-1', 33.5152455, 126.5293636]
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 5개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 6개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 8개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 4개의 검색 결과가 나왔습니다.
# Crawl: 델문도 김녕점, Name: Cafe Delmoondo
# ['델문도 김녕점', 1, '제주 제주시 구좌읍 해맞이해안로 140', 33.542084, 126.8313814]
# 4개의 검색 결과가 나왔습니다.
# Crawl: 카페델마, Name: Cafe Delmar
# ['카페델마', 1, '제주 제주시 연대마을길 16-8', 33.4941899, 126.4260404]
# 0개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 4개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 4개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 4개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 5개의 검색 결과가 나왔습니다.
# Crawl: 보말카페, Name: 보말카페
# ['보말카페', 1, '제주 서귀포시 대정읍 도원로 7', 33.27678815, 126.17126336713818]
# 3개의 검색 결과가 나왔습니다.
# 5개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 3개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 1개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 4개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 4개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 9개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 2개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 9개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
# 0개의 검색 결과가 나왔습니다.
# 10개의 검색 결과가 나왔습니다.
#          name  mention                        address   latitude   longitude
# 0      카페더라이트       52       제주특별자치도 서귀포시 성산읍 한도로 267  33.466171  126.935974
# 1          새빌       24  제주특별자치도 서귀포시 대정읍 노을해안로 216-30  33.246273  126.207174
# 2        제주카페       14                                      None        None
# 3       브라보비치       11   제주특별자치도 서귀포시 성산읍 해맞이해안로 2614  33.477598  126.909302
# 4     웨이뷰 협재점        9           제주 제주시 한림읍 옹포7길 25-3   33.40697  126.254288
# ..        ...      ...                            ...        ...         ...
# 349     도리미노노        1                                      None        None
# 350  델리 미트 제주        1                                      None        None
# 351      더블더블        1                                      None        None
# 352    더 크로플리        1                                      None        None
# 353       힐링집        1                                      None        None
#
# [354 rows x 5 columns]

# %%
cnt1 = 0
cnt2 = 0
for e in lst:
    if len(e) == 5:
        cnt1 += 1
    else:
        cnt2 += 1
print("Result 4")
print(f"   File 1: {f1_cnt:>3} rows")
print(f"   File 2: {f2_cnt:>3} rows")
print(f"   File 3: {f3_cnt:>3} rows")
print(f"    Crawl: {f4_cnt:>3} rows")
print(f"Not Found: {cnt2:>3} rows")
print(f"    Total: {cnt1+cnt2:>3} rows")

final_lst = []
for i in lst:
    final_lst.append(i)
print(final_lst)
# Out:
# Result 4
#    File 1:  21 rows
#    File 2:   1 rows
#    File 3:   2 rows
#     Crawl:  11 rows
# Not Found: 319 rows
#     Total: 354 rows
# [['카페더라이트', 52, '제주특별자치도 서귀포시 성산읍 한도로 267', 33.4661713753033, 126.935973729891], ['새빌', 24, '제주특별자치도 서귀포시 대정읍 노을해안로 216-30', 33.2462728003026, 126.207174417376], ['제주카페', 14, ''], ['브라보비치', 11, '제주특별자치도 서귀포시 성산읍 해맞이해안로 2614', 33.4775976523995, 126.909301990313], ['웨이뷰 협재점', 9, '제주 제주시 한림읍 옹포7
리니티', 1, ''], ['엘핀카페', 1, ''], ['엔와하우스', 1, ''], ['엑스터시', 1, ''], ['에이바', 1, ''], ['에어콘카페', 1, ''], ['에비뉴블루', 1, ''], ['야지니', 1, ''], ['야옹카페', 1, ''], ['애즈', 1, ''], ['애조시티', 1, ''], ['안개산속 택배기사', 1, ''], ['아바쏭', 1, ''], ['아바', 1, '제주특별자치도 제주시 정존15길 5', 33.4858616163857, 126.477891166862], ['아몬드제주', 1, ''], ['제주카페이야기', 1, ''], ['쥬드랑제리', 1, ''], ['젠체인카페', 1, ''], ['티레바', 1, ''], ['프라이메이커', 1, ''], ['풀하우스', 1, '제주특별자치도 제주시 중앙로 60', 33.5131501789142, 126.524683904687], ['푸름까페', 1, ''], ['포베르', 1, ''], ['팔레드뭉클', 1, ''], ['파스쿠찌 제주정류장', 1, ''], ['파라오카페', 1, ''], ['티에르티에', 1, ''], ['탐폰카페', 1, ''], ['별다방', 1, '제주 제주시 산지로 3-1', 33.5152455, 126.5293636], ['탐나', 1, ''], ['클롭 기념타워점', 1, ''], ['크아페 크래프트카페', 1, ''], ['코마코마', 1, ''], ['커피인제주', 1, ''], ['커피옥션', 1, ''], ['커피앙고라', 1, ''], ['커피소라', 1, ''], ['플라도 브런치', 1, ''], ['플라워', 1, '제주특별자치도 제주시 애월읍 애월해안로 454-5', 33.4765726362278, 126.354227237736], ['플라잉오렌지', 1, ''], ['플로라', 1, '제주특별자치도 제주시 중앙로 249', 33.5174208, 126.5247977], ['흑돼지마을 카페', 1, ''], ['흑돼지 됫마루 국밥식당', 1, ''], ['호일', 1, ''], ['햄커피', 1, ''], ['해화당', 1, ''], ['해맞이', 1, '제주특별자치도 제주시 공설로 41', 33.4993163, 126.5164068], ['해달', 1, ''], ['해녀횟집', 1, '제주특별자치도 제주시 한경면 노을해안로', '33.30794881', '126.16405'], ['해결사', 1, ''], ['합동산디자인펍', 1, ''], ['할리스 제주신', 1, ''], ['하이신성', 1, ''], ['하이버드 제주', 1, ''], ['하얼빈카페', 1, ''], ['하비터', 1, ''], ['하맛앤그릴', 1, ''], ['하리우드', 1, ''], ['커피볶는섬', 1, ''], ['커피몽타주', 1, ''], ['젠틀레이디', 1, ''], ['카킷', 1, ''], ['카페 앞마당 ...

# %%
final_result = []
final_result.append(['name', 'mention', 'address', 'latitude', 'longitude', 'type'])
for e in final_lst:
    if len(e) == 5:
        e.append(0)
        print(e)
        final_result.append(e)
print(len(final_result))

with open('output2.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerows(final_result)
# Out:
# ['카페더라이트', 52, '제주특별자치도 서귀포시 성산읍 한도로 267', 33.4661713753033, 126.935973729891, 0]
# ['새빌', 24, '제주특별자치도 서귀포시 대정읍 노을해안로 216-30', 33.2462728003026, 126.207174417376, 0]
# ['브라보비치', 11, '제주특별자치도 서귀포시 성산읍 해맞이해안로 2614', 33.4775976523995, 126.909301990313, 0]
# ['웨이뷰 협재점', 9, '제주 제주시 한림읍 옹포7길 25-3', 33.4069704, 126.254288, 0]
# ['마음에온', 8, '제주 제주시 칠성로길 29-1', 33.5144683, 126.5262182, 0]
# ['쉬어갓', 5, '제주특별자치도 서귀포시 성산읍 일주동로 5023', 33.3860851013057, 126.882329800264, 0]
# ['위이', 5, '제주특별자치도 서귀포시 안덕면 신화역사로682번길 12', 33.3127519347285, 126.359105799759, 0]
# ['지구상회', 5, '제주특별자치도 제주시 애월읍 애월해안로 715', 33.4840001976835, 126.377379932118, 0]
# ['하라케케', 4, '제주특별자치도 서귀포시 속골로 29-10', 33.2428543200944, 126.527782166788, 0]
# ['커피템플', 2, '제주특별자치도 제주시 영평길 269', 33.4781538312649, 126.57030222334, 0]
# ['카페마음마루', 2, '제주 제주시 아란14길 3', 33.4711333, 126.5441525, 0]
# ['어린왕자감귤밭', 2, '제주특별자치도 서귀포시 대정읍 추사로36번길 45-1', 33.2532868801428, 126.281885810743, 0]
# ['한라산', 2, '제주특별자치도 서귀포시 표선면 중산간동로 4669', 33.3890832377531, 126.797005141356, 0]
# ['웨스트그라운드', 1, '제주 제주시 한경면 신한로 183-16', 33.347143, 126.1897426, 0]
# ['파이굽는 돌담집', 1, '제주 제주시 아란9길 48', 33.4717481, 126.5406229, 0]
# ['르브아 커피', 1, '제주 서귀포시 남원읍 태위로266번길 15', 33.2739606, 126.676409, 0]
# ['신촌구옥', 1, '제주특별자치도 제주시 조천읍 신촌3길 13', 33.5342390713234, 126.618578611865, 0]
# ['숨', 1, '제주특별자치도 제주시 대동길 18', 33.4929905983585, 126.463089375824, 0]
# ['서귀샌드', 1, '제주특별자치도 서귀포시 태평로 347', 33.2468138986737, 126.557921148334, 0]
# ['착한놀부 신화월드 본점', 1, '제주 제주시 한경면 중산간서로 3690', 33.3100579, 126.2383704, 0]
# ['아바', 1, '제주특별자치도 제주시 정존15길 5', 33.4858616163857, 126.477891166862, 0]
# ['풀하우스', 1, '제주특별자치도 제주시 중앙로 60', 33.5131501789142, 126.524683904687, 0]
# ['별다방', 1, '제주 제주시 산지로 3-1', 33.5152455, 126.5293636, 0]
# ['플라워', 1, '제주특별자치도 제주시 애월읍 애월해안로 454-5', 33.4765726362278, 126.354227237736, 0]
# ['플로라', 1, '제주특별자치도 제주시 중앙로 249', 33.5174208, 126.5247977, 0]
# ['해맞이', 1, '제주특별자치도 제주시 공설로 41', 33.4993163, 126.5164068, 0]
# ['해녀횟집', 1, '제주특별자치도 제주시 한경면 노을해안로', '33.30794881', '126.16405', 0]
# ['챔피온', 1, '제주특별자치도 제주시 방일4길 4', 33.4775317663594, 126.468429620974, 0]
# ['사랑채', 1, '제주특별자치도 제주시 원남6길 11', 33.4882861202363, 126.5293450668, 0]
# ['델문도 김녕점', 1, '제주 제주시 구좌읍 해맞이해안로 140', 33.542084, 126.8313814, 0]
# ['카페델마', 1, '제주 제주시 연대마을길 16-8', 33.4941899, 126.4260404, 0]
# ['보말카페', 1, '제주 서귀포시 대정읍 도원로 7', 33.27678815, 126.17126336713818, 0]
# ['베네딕트', 1, '제주특별자치도 서귀포시 대정읍 구억중앙로 11-21', 33.2731630899351, 126.282956214982, 0]
# ['공간', 1, '제주특별자치도 제주시 애월읍 하소로 506', 33.4377038083484, 126.393178659755, 0]
# ['레이어드', 1, '제주특별자치도 서귀포시 일주서로 426', 33.253561851469, 126.463399736196, 0]
# 36
